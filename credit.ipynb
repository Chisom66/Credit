# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px

# %%
credit = pd.read_csv("Credit_card.csv")
credit
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 2     5009746      F         Y             N         0       315000.0
# 3     5009749      F         Y             N         0            NaN
# 4     5009752      F         Y             N         0       315000.0
# ...       ...    ...       ...           ...       ...            ...
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# ...

# %%
credit2 = pd.read_csv("Credit_card_label.csv")
credit2
# Out:
#        Ind_ID  label
# 0     5008827      1
# 1     5009744      1
# 2     5009746      1
# 3     5009749      1
# 4     5009752      1
# ...       ...    ...
# 1543  5028645      0
# 1544  5023655      0
# 1545  5115992      0
# 1546  5118219      0
# 1547  5053790      0
#
# [1548 rows x 2 columns]

# %%
merged_credit = pd.merge(credit, credit2, on='Ind_ID', how='inner')
merged_credit
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 2     5009746      F         Y             N         0       315000.0
# 3     5009749      F         Y             N         0            NaN
# 4     5009752      F         Y             N         0       315000.0
# ...       ...    ...       ...           ...       ...            ...
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# ...

# %%
credit.isnull().sum()*100/len(credit)
# Out:
# Ind_ID              0.000000
# GENDER              0.452196
# Car_Owner           0.000000
# Propert_Owner       0.000000
# CHILDREN            0.000000
# Annual_income       1.485788
# Type_Income         0.000000
# EDUCATION           0.000000
# Marital_status      0.000000
# Housing_type        0.000000
# Birthday_count      1.421189
# Employed_days       0.000000
# Mobile_phone        0.000000
# Work_Phone          0.000000
# Phone               0.000000
# EMAIL_ID            0.000000
# Type_Occupation    31.524548
# Family_Members      0.000000
# dtype: float64

# %%
credit['Type_Occupation'].fillna('unknown', inplace=True)

# %%
credit["Type_Income"].nunique()
# Out:
# 4

# %%
credit["Type_Occupation"].nunique()
# Out:
# 19

# %%
credit["Type_Occupation"].value_counts()*100/len(credit)
# Out:
# Type_Occupation
# unknown                  31.524548
# Laborers                 17.312661
# Core staff               11.240310
# Managers                  8.785530
# Sales staff               7.881137
# Drivers                   5.555556
# High skill tech staff     4.198966
# Medicine staff            3.229974
# Accountants               2.842377
# Security staff            1.614987
# Cleaning staff            1.421189
# Cooking staff             1.356589
# Private service staff     1.098191
# Low-skill Laborers        0.581395
# Secretaries               0.581395
# Waiters/barmen staff      0.322997
# HR staff                  0.193798
# IT staff                  0.129199
# Realty agents             0.129199
# Name: count, dtype: float64

# %%
credit["Type_Income"].value_counts()*100/len(credit)
# Out:
# Type_Income
# Working                 51.550388
# Commercial associate    23.578811
# Pensioner               17.377261
# State servant            7.493540
# Name: count, dtype: float64

# %%
credit["EDUCATION"].nunique()
# Out:
# 5

# %%
credit["Birthday_count_years"] = credit["Birthday_count"]/365
credit["Birthday_count_years"]   #print(credit)
# Out:
# 0      -51.430137
# 1      -37.142466
# 2             NaN
# 3      -37.142466
# 4      -37.142466
#           ...
# 1543   -32.758904
# 1544   -28.024658
# 1545   -36.093151
# 1546   -41.895890
# 1547   -45.482192
# Name: Birthday_count_years, Length: 1548, dtype: float64

# %%
credit["Birthday_count_years"].nunique()
# Out:
# 1270

# %%
Birth_count_avg = credit["Birthday_count_years"].mean()
Birth_count_avg
# Out:
# -43.94614265965278

# %%
Birth_count_avg2 = credit["Birthday_count_years"].min()
Birth_count_avg2
# Out:
# -68.34520547945205

# %%
Birth_count_avg3 = credit["Birthday_count_years"].max()
Birth_count_avg3
# Out:
# -21.10958904109589

# %%
plt.figure(figsize=(12, 4))
sns.countplot(x = "Car_Owner", hue= "EDUCATION", data = credit)
# Out:
# <Axes: xlabel='Car_Owner', ylabel='count'>

# %%
piechart = px.pie(credit, names = 'EDUCATION', values = 'Annual_income')
piechart.show()

# %%
credit_xx = credit.select_dtypes(include=['Int64'])
corr_matrix = credit_xx.corr()
plt.figure(figsize=(17, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=.9)
plt.title('Sample Heatmap')
# Out:
# Text(0.5, 1.0, 'Sample Heatmap')

# %%
sns.countplot(x = "GENDER", data = credit)
# Out:
# <Axes: xlabel='GENDER', ylabel='count'>

# %%
sns.countplot(x = "label", data = merged_credit)
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
credit["GENDER"].value_counts()*100/len(credit)
# Out:
# GENDER
# F    62.855297
# M    36.692506
# Name: count, dtype: float64

# %%
merged_credit["label"].value_counts()*100/len(merged_credit)
# Out:
# label
# 0    88.69509
# 1    11.30491
# Name: count, dtype: float64

# %%
plt.figure(figsize=(12, 4))
sns.countplot(x = "label", hue= "Car_Owner", data = merged_credit)
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
plt.figure(figsize=(12, 4))
sns.countplot(x = "label", hue= "Housing_type", data = merged_credit)
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
merged_credit_filtered = merged_credit[merged_credit['label'] >= 1]
merged_credit_filtered
#I leftbehind only the rows of clients that were approved.
# Out:
#       Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0    5008827      M         Y             Y         0       180000.0
# 1    5009744      F         Y             N         0       315000.0
# 2    5009746      F         Y             N         0       315000.0
# 3    5009749      F         Y             N         0            NaN
# 4    5009752      F         Y             N         0       315000.0
# ..       ...    ...       ...           ...       ...            ...
# 170  5149190      M         Y             N         1       450000.0
# 171  5149192    NaN         Y             N         1       450000.0
# 172  5149828      M         Y             Y         0       315000.0
# 173  5149834      F         N             Y         0       157500.0
# 174  5149838      F         N             Y         0       157500.0
#
#               Type_Income                      EDUCATION Marital_status  \
# ...

# %%
piechart = px.pie(merged_credit_filtered, names = 'EDUCATION', values = 'Annual_income')
piechart.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x = "label", hue= "Car_Owner", data = merged_credit_filtered)
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
credit["Car_Owner"].value_counts()*100/len(merged_credit_filtered)
# Out:
# Car_Owner
# N    528.000000
# Y    356.571429
# Name: count, dtype: float64

# %%
credit["GENDER"].value_counts()*100/len(merged_credit_filtered)
# Out:
# GENDER
# F    556.000000
# M    324.571429
# Name: count, dtype: float64

# %%
merged_credit_filtered["Birthday_count_years"] = merged_credit_filtered["Birthday_count"]/365
merged_credit_filtered["Birthday_count_years"]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1080\2985122297.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0     -51.430137
# 1     -37.142466
# 2            NaN
# 3     -37.142466
# 4     -37.142466
#          ...
# 170   -26.978082
# 171   -26.978082
# 172   -47.528767
# 173   -33.936986
# 174   -33.936986
# Name: Birthday_count_years, Length: 175, dtype: float64

# %%
Birth_count_avg2 = merged_credit_filtered["Birthday_count_years"].mean()
Birth_count_avg2
# Out:
# -45.40707894528467

# %%
Birth_count_avg2 = merged_credit_filtered["Birthday_count_years"].min()
Birth_count_avg2
# Out:
# -67.42739726027398

# %%
Birth_count_avg2 = merged_credit_filtered["Birthday_count_years"].max()
Birth_count_avg2
# Out:
# -24.4027397260274
